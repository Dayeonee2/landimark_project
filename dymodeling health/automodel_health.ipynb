# %% [markdown]
# 트레이닝 되지 않은 AutoModel, AutoTokenizer 로 pretrained된 BERT 모델을 로드하고,
#
# 코사인유사도를 계산하여 코사인유사도가 가장 높은 답변을 제공합니다.
#
# 임베딩은 사전 계산되어 계산 속도를 개선합니다.

# %%
import pandas as pd

df = pd.read_csv('file/health_result_label.csv')
df.head()

# 질문 리스트
questions = df['question'].tolist()
answers = df['answer'].tolist()

# %%
import torch
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModel

# BERT 모델과 토크나이저 로드
tokenizer = AutoTokenizer.from_pretrained("beomi/KcBERT-base")
model = AutoModel.from_pretrained("beomi/KcBERT-base")

question_embeddings = torch.load('embeddings/question_embeddings.pth', weights_only=True)

# 입력 문장을 임베딩으로 변환
def get_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1)  # 임베딩 벡터 반환

# 입력 질문과 사전 임베딩 간의 코사인 유사도 계산
def find_most_similar_answer(input_question, question_embeddings, answers):
    input_embedding = get_embedding(input_question)  # 입력 질문 임베딩

    max_similarity = -1
    best_answer = None

    # 각 사전 계산된 질문 임베딩과 유사도 비교
    for i, question_embedding in enumerate(question_embeddings):
        similarity = F.cosine_similarity(input_embedding, question_embedding).item()

        if similarity > max_similarity:
            max_similarity = similarity
            best_answer = answers[i]

    return best_answer, max_similarity

# 입력 질문 예시
input_question = "정수기 위치가 어디죠?"
answers = df['answer'].tolist()

# 유사도 기반 답변 찾기
answer, max_similarity = find_most_similar_answer(input_question, question_embeddings, answers)
print("챗봇 답변:", answer)
print("유사도:", max_similarity)
# Out:
# 챗봇 답변: 위치 정보를 조회하겠습니다. 병원에서 50m 떨어져 있는 곳에 위치해 있습니다.
# 유사도: 0.8512148857116699

# %%
## test_questions 데이터프레임 읽기
test_questions = pd.read_csv('file/test_questions_with_labels.csv')

# 모든 질문을 리스트로 변환하여 input_questions에 저장
input_questions = test_questions['question'].tolist()

# 결과를 저장할 리스트 초기화
results = []

# 각 질문에 대해 챗봇 응답 호출
for input_question in input_questions:
    answer, max_similarity = find_most_similar_answer(input_question, question_embeddings, answers)
    
    results.append({
        'input_question': input_question,
        'answer': answer,
       'max_similarity': max_similarity
    })
    
# 결과를 데이터프레임으로 변환
results_df = pd.DataFrame(results)

# 결과 출력
results_df[:30]
# Out:
#                                      input_question  \
# 0                                    화상연고도 처방이 되나요?
# 1                       오늘 두시 삼십분에 예약했어요. 언제 들어가나요?
# 2                    예약한 시간보다 조금 늦었어요. 다시 접수해야 하나요?
# 3                              피가 계속 나는데, 저 죽는 걸까요?
# 4                                     접수 재등록해도 되나요?
# 5                       접수 시간이 지났는데 혹시 대기순번이 넘어갔나요?
# 6                                  접수가 왜이렇게 오래 걸려요?
# 7                   다음에 들어가는 순번인데, 잠깐 화장실 다녀와도 되나요?
# 8                                           접수하려고요.
# 9                                     진료 접수 어떻게 하죠?
# 10                                오래된 상처 흉터도 없어질까요?
# 11                       여기 한의원도 같이 하나요? 침을 맡고 싶어요.
# 12           목 디스크 때문에 잠을 잘 수 없어요. 어떤 치료를 받을 수 있나요?
# 13   탈모 초기 인 것 같아요. 머리카락이 자꾸 빠지는데, 이것도 진료를 볼 수 있나요?
# 14      저는 아니고, 제 아이가 열이 자꾸 오르다 말다 해요. 소아과도 진료 하나요?
# 15  이번주에 결혼식이라 몸살이 빨리 나아야 하는데, 비타민 주사 같은거 맞을 수 있나요?
# 16                      어제부터 배가 아프고 열도 계속 나는 거 같아요.
# 17                                       목소리가 안나와요.
# 18                                 지난주부터 몸살기가 있었어요.
# 19                       장염 나은지 얼마 안됐는데, 또 걸린거 같아요.
# 20                   아이가 넘어져서 팔꿈치가 까졌는데, 진물이 계속 나요.
# 21                       도대체 대기실이 어디에요? 어디로 가라는거에요?
# 22                저는 몇 번 째에 들어가나요? 진료예약을 아까전에 했는데요.
# 23                                  대기시간이 얼마나 남은거죠?
# 24                       진료실이 저기로 가면 되나요? 어느 방향이에요?
# 25           저 다음대기순번인데, 전화만 받고 들어가도 되나요? 미룰 수 있나요?
# 26                                     대기실로 안내해주세요.
# 27                                 진료실 옆에 대기실이 있나요?
# 28                                      진료실이 1층인가요?
# 29                       대기실에서 기다리라고 했는데, 어디서 기다려요?
#
#                                                answer  max_similarity
# 0           저희 병원에서 사용되는 의약품은 아래층에 행복 약국에서 구매가 가능합니다.        0.713620
# 1        어서 오십시오. 성함과 연락처를 앞에 적어주시면 확인 후 접수 도와드리겠습니다.        0.842398
# 2                             대기하시기 전에 접수증 작성 부탁드립니다.        0.857856
# 3   긴급상황이라면 응급실로 이동하셔서 진료 보실 수 있습니다. 응급실 건물로 가주시면 ...        0.830222
# 4               마감 정산이 필요하여 지금 수납해 주시면 원활한 처리가 가능합니다.        0.777209
# 5                   확인해 도와드리겠습니다. 합의된 사항인지 확인이 필요합니다.        0.818078
# 6         앞서 이용해 주시는 손님이 많았습니다. 조금만 양해 부탁드립니다. 죄송합니다.        0.826650
# 7            네 알겠습니다. 다녀오시면 앞에 보이시는 2번 진료실로 들어가 주십시오.        0.823663
# 8            현재 30분 정도 대기하셔야 합니다. 진료 접수 도와드리도록 하겠습니다.        0.782673
# 9               바로 도와드리겠습니다. 옆쪽 통로를 통해 접수창구로 가시면 됩니다.        0.888841
# 10                    미용 목적의 수술의 경우 진단서 발급이 따로 어렵습니다.        0.644710
# 11                       정수기는 진료 대기실 앞쪽에 있습니다. 감사합니다.        0.720050
# 12                       진료는 진료실에서 전문가와 함께 상담 부탁드립니다.        0.833728
# 13          체온 측정을 데스크에서 도와드리겠습니다. 데스크로 이동해 주시기 바랍니다.        0.827194
# 14  평범한 감기일 수도 있으니까 너무 걱정 마십시오. 열이 나는 것 이외에 증상 있으십니까?        0.768946
# 15                   예약 가능 시간을 조회 중입니다. 대기해 주시기 바랍니다.        0.796177
# 16                        자세한 진료를 위해 간단한 검사를 실시하겠습니다.        0.819470
# 17      스트레스를 많이 받았을 경우 일시적 증상이 생길 수 있습니다. 확인이 필요합니다.        0.719295
# 18                               증상을 원장님께 전달해 드리겠습니다.        0.760311
# 19     총 5회의 물리치료가 예정되어 있습니다. 치료를 더 받아야 증상이 호전될 것입니다.        0.776125
# 20                  해당 내용을 담당 선생님께 전달해 드리겠습니다. 감사합니다.        0.795169
# 21                    대기실 안내를 시작하겠습니다. 직접 안내해 드리겠습니다.        0.817961
# 22  예약시간 10분이 넘어가면 자동 예약 취소됩니다. 현장 접수하시고 대기해 주시길 바...        0.795576
# 23  대기인원이 있어 정확한 대기 시간을 말씀드리기 어렵습니다. 이쪽 대기실에 앉아 주십시오.        0.768267
# 24       진료실은 지하 2층에 있습니다. 왼쪽에 있는 엘리베이터를 이용하실 수 있습니다.        0.886487
# 25           죄송합니다. 현재는 예약 손님 우선 진료 중이오니 조금만 기다려 주세요.        0.786038
# 26                저를 따라 오시기 바랍니다. 2번 대기실로 안내해 드리겠습니다.        0.822344
# 27                 복도를 지나면 바로 보입니다. 대기실까지 안내해 드리겠습니다.        0.935537
# 28            진료실과 조금 떨어진 곳에 있습니다. 제가 직접 안내 도와드리겠습니다.        0.837516
# 29                   청력 검사 대기실은 왼쪽 복도로 직진하시면 위치해있습니다.        0.903921

# %%
# 결과를 CSV 파일로 저장
# results_df.to_csv('result csv/chatbot_responses_auto.csv', index=False)
